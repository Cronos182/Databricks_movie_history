# %%
bronze_folder_path = "abfss://bronze@moviehistory182.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviehistory182.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviehistory182.dfs.core.windows.net"
