# %%
spark.read.option("header",True).csv("abfss://bronze@moviehistory182.dfs.core.windows.net/2024-12-23/movie.csv").createOrReplaceTempView("v_movie_2")

# %%
# %sql
SELECT COUNT(1) FROM v_movie_2;

# %%
spark.read.option("header",True).csv("abfss://bronze@moviehistory182.dfs.core.windows.net/2024-12-30/movie.csv").createOrReplaceTempView("v_movie_3")

# %%
# %sql
SELECT COUNT(1) FROM v_movie_3;

# %% [markdown]
# ### Ingestion del archivo "movie.csv"

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("p_environment", "")
v_environment = dbutils.widgets.get("p_environment")

# %%
dbutils.widgets.text("p_file_date", "2024-12-30")
v_file_date = dbutils.widgets.get("p_file_date")

# %%
# %run "../includes/configuration"

# %%
# %run "../includes/commom_functions"

# %% [markdown]
# #### Paso 1 - Leer el archivo CSV usando "DataFrameReader" de Spark

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, DoubleType, StringType, DateType

# %%
movie_schema = StructType( fields= [
    StructField("movieId", IntegerType(), False),
    StructField("title", StringType(), True),
    StructField("budget", DoubleType(), True),
    StructField("homePage", StringType(), True),
    StructField("overview", StringType(), True),
    StructField("popularity", DoubleType(), True),
    StructField("yearReleaseDate", IntegerType(), True),
    StructField("releaseDate", DateType(), True),
    StructField("revenue", DoubleType(), True),
    StructField("durationTime", IntegerType(), True),
    StructField("movieStatus", StringType(), True),
    StructField("tagline", StringType(), True),
    StructField("voteAverage", DoubleType(), True),
    StructField("voteCount", IntegerType(), True)
])

# %%
movie_df = spark.read \
    .option("header",True) \
    .schema(movie_schema) \
    .csv(f"{bronze_folder_path}/{v_file_date}/movie.csv")

# %%
# movie_df = spark.read \
#     .option("header",True) \
#     .option("inferSchema",True) \
#     .csv("abfss://bronze@moviehistory182.dfs.core.windows.net/movie.csv")

# %%
type(movie_df)

# %%
movie_df.show()

# %%
display(movie_df)

# %%
movie_df.printSchema()

# %%
display(movie_df.describe())

# %% [markdown]
# #### Paso 2 - Seleccionar sólo las columnas "requeridas"

# %%
# movies_selected_df = movie_df.select("movieId","title","budget","popularity","yearReleaseDate","releaseDate","revenue","durationTime","voteAverage","voteCount")

# %%
# movies_selected_df = movie_df.select(movie_df.movieId,movie_df.title,movie_df.budget,movie_df.popularity,movie_df.yearReleaseDate,movie_df.releaseDate,movie_df.revenue,movie_df.durationTime,movie_df.voteAverage,movie_df.voteCount)

# %%
# movies_selected_df = movie_df.select(movie_df["movieId"], movie_df["title"], movie_df["budget"], movie_df["popularity"], movie_df["yearReleaseDate"], movie_df["releaseDate"], movie_df["revenue"], movie_df["durationTime"], movie_df["voteAverage"], movie_df["voteCount"])

# %%
from pyspark.sql.functions import col

# %%
movies_selected_df = movie_df.select(col("movieId"), col("title"), col("budget"), col("popularity"), col("yearReleaseDate"), col("releaseDate"), col("revenue"), col("durationTime"), col("voteAverage"), col("voteCount"))

# %% [markdown]
# #### Paso 3 - Cambiar el nombre de las columnas según lo "requerido"

# %%
movies_renamed_df = movies_selected_df \
    .withColumnRenamed("movieId", "movie_id") \
    .withColumnRenamed("yearReleaseDate", "year_release_date") \
    .withColumnRenamed("releaseDate", "release_date") \
    .withColumnRenamed("durationTime", "duration_time") \
    .withColumnRenamed("voteAverage", "vote_average") \
    .withColumnRenamed("voteCount", "vote_count")

# %% [markdown]
# #### Paso 4 - Agregar la columna "ingestion_date" al DataFrame

# %%
from pyspark.sql.functions import current_timestamp, lit

# %%
movies_final_df = add_ingestion_date(movies_renamed_df) \
                  .withColumn("environment", lit(v_environment)) \
                  .withColumn("file_date", lit(v_file_date))

# %% [markdown]
# #### Paso 5 - Escribir datos en el datalake en formato "Parquet"

# %%
# movies_final_df.write.mode("overwrite").partitionBy("year_release_date").parquet(f"{silver_folder_path}/movies")

# %%
# movies_final_df.write.mode("overwrite").format("delta").saveAsTable("movie_silver.movies")

# %%
# if spark.catalog.tableExists("movie_silver.movies"):
#     spark.sql(f"DELETE FROM movie_silver.movies WHERE file_date = '{v_file_date}'")

# %%
# def overwrite_partition(db_name, table_name, column_partition, file_date):
#     if spark.catalog.tableExists(f"{db_name}.{table_name}"):
#         spark.sql(f"DELETE FROM {db_name}.{table_name} WHERE {column_partition} = '{file_date}'")

# %%
# overwrite_partition("movie_silver", "movies", "file_date", v_file_date)

# %%
# movies_final_df.write.mode("append").partitionBy("file_date").format("delta").saveAsTable("movie_silver.movies")

# %%
merge_condition = 'tgt.movie_id = src.movie_id AND tgt.file_date = src.file_date'
merge_delta_lake(movies_final_df, "movie_silver", "movies", merge_condition, "file_date")

# %%
# %sql 
SELECT file_date, COUNT(1) 
FROM movie_silver.movies
GROUP BY file_date;

# %%
# %sql
DESC EXTENDED movie_silver.movies;

# %%
# %fs
# ls abfss://silver@moviehistory182.dfs.core.windows.net/movies

# %%
# display(spark.read.parquet("abfss://silver@moviehistory182.dfs.core.windows.net/movies"))

# %%
dbutils.notebook.exit("Success")
