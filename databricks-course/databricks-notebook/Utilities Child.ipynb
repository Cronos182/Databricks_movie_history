# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("p_msg", "", "Parámetro de Entrada")

# %%
v_msg = dbutils.widgets.get("p_msg")

# %%
print("Soy hijo del notebook: Utilities Introduction " + v_msg)

# %%
dbutils.notebook.exit("Ejecución con exito.")
